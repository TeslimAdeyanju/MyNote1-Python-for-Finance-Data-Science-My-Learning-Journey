# %%
from my_project.mytools import say_hello, add

# %%
print(say_hello("Alice"))  # Output: Hello, Alice!
print(add(2, 3))
# Out:
# Hello, Alice!
# 5

# %%
from my_project.mytools import say_hello, add

print(say_hello("Alicex"))  # Output: Hello, Alice!
print(add(2, 31))
# Out:
# Hello, Alicex!
# 33

# %%
from fin import (remove_null_values, 
                 format_currency, 
                 remove_duplicates, 
                 is_valid_amount)

# %%
# Example: Clean transaction data
transactions = [100.50, None, 200.75, '', 150.00, 100.50]

# %%
clean_data = remove_null_values(transactions)
print(f"Clean data: {clean_data}")
# Out:
# Clean data: [100.5, 200.75, 150.0, 100.5]

# %%
# Remove duplicates
unique_transactions = remove_duplicates(clean_data)
print(f"Unique transactions: {unique_transactions}")
# Out:
# Unique transactions: [200.75, 100.5, 150.0]

# %%
# Format currency
for amount in unique_transactions:
    if is_valid_amount(amount):
        print(format_currency(amount))
# Out:
# $200.75
# $100.50
# $150.00

# %%
import sys

print("Python executable location:")
print(sys.executable)  # Shows which Python you’re running

print("\nPython search paths:")
for i, path in enumerate(sys.path):
    print(f"{i+1:2d}. {path}")
# Out:
# Python executable location:
# /Users/teslim/anaconda3/envs/machine-learning-env/bin/python
#
# Python search paths:
#  1. /Users/teslim/anaconda3/envs/machine-learning-env/lib/python310.zip
#  2. /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10
#  3. /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10/lib-dynload
#  4.
#  5. /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10/site-packages

# %%
import sys

print("Python executable location:")
print(sys.executable)  # Shows which Python you’re running

print("\nPython search paths:")
for i, path in enumerate(sys.path):
    print(f"{i+1:2d}. {path}")
# Out:
# Python executable location:
# /Users/teslim/anaconda3/envs/machine-learning-env/bin/python
#
# Python search paths:
#  1. /Users/teslim/anaconda3/envs/machine-learning-env/lib/python310.zip
#  2. /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10
#  3. /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10/lib-dynload
#  4.
#  5. /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10/site-packages
